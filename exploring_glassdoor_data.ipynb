# %%
import pandas as pd

df = pd.read_csv('all_reviews.csv')

df['date'] = pd.to_datetime(df['date'])

# numeric_cols = [
#     'Career Opportunities' 
#     ,'Compensation and Benefits' 
#     ,'Senior Management' 
#     ,'Work/Life Balance' 
#     ,'Culture & Values'
#     ,'Diversity & Inclusion'
#     ]

# for col in numeric_cols:
#     df[col] = pd.to_numeric(df[col])
# Out:
# /tmp/ipykernel_6038/2889640620.py:3: DtypeWarning: Columns (5,9,10,11,12) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('all_reviews.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9901889 entries, 0 to 9901888
# Data columns (total 19 columns):
#  #   Column                     Dtype
# ---  ------                     -----
#  0   rating                     float64
#  1   title                      object
#  2   status                     object
#  3   pros                       object
#  4   cons                       object
#  5   advice                     object
#  6   Recommend                  object
#  7   CEO Approval               object
#  8   Business Outlook           object
#  9   Career Opportunities       object
#  10  Compensation and Benefits  object
#  11  Senior Management          object
#  12  Work/Life Balance          object
#  13  Culture & Values           float64
#  14  Diversity & Inclusion      float64
#  15  firm_link                  object
#  16  date                       object
#  17  job                        object
#  18  index                      float64
# dtypes: float64(4), object(15)
# memory usage: 1.4+ GB

# %%
df.sample(5)
# Out:
#          rating                                      title  \
# 268818      3.0                              pros and cons
# 78681       2.0                     It’s a consulting firm
# 6218674     5.0                             Talent Manager
# 7410445     5.0                            I need job asap
# 9310132     4.0  It is a good company to start your career
#
#                                       status  \
# 268818                      Current Employee
# 78681                        Former Employee
# 6218674   Current Employee, more than 1 year
# 7410445                      Former Employee
# 9310132  Current Employee, more than 3 years
#
#                                                       pros  \
# 268818       pay benefits paid time off discounts holidays
# 78681    You get to work in different verticals and ind...
# 6218674  Fun work environment, opportunity to network w...
# 7410445  They do help a lot with deaf people. They ensu...
# 9310132                the work schedule is quite flexible
#
#                                                       cons advice Recommend  \
# 268818   management \r\nculture\r\nwork life balance\r\...    NaN         o
# 78681    Work pressure, if you are non billable then it...    NaN         o
# 6218674  long hours - can be hard work because you are ...    NaN         v
# 7410445                 They still can do better than that    NaN         v
# 9310132                        Salary is paid below market    NaN         o
#
#         CEO Approval Business Outlook Career Opportunities  \
# 268818             o                r                    3
# 78681              o                o                    1
# 6218674            v                v                    5
# 7410445            r                r                  5.0
# 9310132            o                o                    3
#
#         Compensation and Benefits Senior Management Work/Life Balance  \
# 268818                          4                 1                 3
# 78681                           3                 2                 2
# 6218674                         5                 5                 5
# 7410445                       5.0               3.0               5.0
# 9310132                         2                 2                 5
#
#          Culture & Values  Diversity & Inclusion  \
# 268818                1.0                    NaN
# 78681                 2.0                    NaN
# 6218674               5.0                    NaN
# 7410445               2.0                    3.0
# 9310132               4.0                    5.0
#
#                                                  firm_link       date  \
# 268818   https://www.glassdoor.com/Reviews/Nordstrom-Re... 2017-12-04
# 78681                     Reviews/CGI-Reviews-E1513026.htm 2019-09-19
# 6218674  https://www.glassdoor.com/Reviews/Kforce-Revie... 2018-12-17
# 7410445  https://www.glassdoor.com/Reviews/Amazon-Revie... 2022-09-09
# 9310132                       Reviews/SLB-Reviews-E588.htm 2021-02-09
#
#                                  job  index
# 268818                                  NaN
# 78681              Senior Consultant    NaN
# 6218674   Talent Acquisition Manager    NaN
# 7410445          Warehouse Associate    5.0
# 9310132       Sap deployment analyst    NaN

# %%
print(df.groupby(df['date'].dt.year).size())
# Out:
# date
# 2008.0      38358
# 2009.0      42916
# 2010.0      81826
# 2011.0     104395
# 2012.0     192190
# 2013.0     243981
# 2014.0     404973
# 2015.0     667439
# 2016.0     748514
# 2017.0     760680
# 2018.0     684241
# 2019.0     721680
# 2020.0     963670
# 2021.0    1959787
# 2022.0    1796544
# 2023.0     490524
# dtype: int64
