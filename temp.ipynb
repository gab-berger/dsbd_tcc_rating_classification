# %%
import pickle
import pandas as pd

pickle_file = 'sbert/sbert_data.pickle'
df = pd.read_pickle(pickle_file)

# %%
print(df.info())
print(df.head())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8 entries, 0 to 7
# Data columns (total 14 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   model                     8 non-null      object
#  1   num_clusters              8 non-null      object
#  2   clustering_time           8 non-null      object
#  3   run_datetime              8 non-null      object
#  4   inertia                   8 non-null      float64
#  5   silhouette_avg            8 non-null      float32
#  6   silhouette_avg            8 non-null      float32
#  7   db_index                  8 non-null      float64
#  8   ch_index                  8 non-null      float32
#  9   silhouette_avg_clusters   8 non-null      object
#  10  max_iterations            8 non-null      object
#  11  description_time          8 non-null      object
#  12  cluster_description_dict  8 non-null      object
# ...

# %%
display(df.head())
# Out:
#                         model num_clusters clustering_time    run_datetime  \
# 0            all-MiniLM-L6-v2           10               3  24.10.29_21.59
# 1            all-MiniLM-L6-v2           10               3  24.10.29_22.01
# 2    paraphrase-MiniLM-L12-v2           10               4  24.10.29_22.01
# 3  msmarco-distilbert-base-v4           10               5  24.10.29_22.01
# 4        all-distilroberta-v1           10               5  24.10.29_22.01
#
#         inertia  silhouette_avg  silhouette_avg  db_index   ch_index  \
# 0    263.997328        0.122166        0.122166  2.902176  22.420395
# 1    268.391188        0.088475        0.088475  3.099655  21.162037
# 2   6491.937233        0.092828        0.092828  2.820132  23.369865
# 3  46940.722616        0.119732        0.119732  2.612964  22.618380
# 4    269.748443        0.078056        0.078056  3.191459  19.848055
#
#                              silhouette_avg_clusters max_iterations  \
# ...
